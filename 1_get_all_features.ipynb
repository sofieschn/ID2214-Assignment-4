# %% [markdown]
# # Feature Extraction from SMILES Data
#
# This notebook extracts chemical features from SMILES (Simplified Molecular Input Line Entry System) strings for machine learning purposes.
#
# **Goal:** Convert molecular structures into numerical features that can be used to predict if a molecule is biologically active.

# %% [markdown]
# ### Import Required Libraries
#
# - **pandas/numpy**: Data manipulation
# - **sklearn**: Machine learning tools (for later use)
# - **warnings**: Suppress warnings for cleaner output

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Load Data
#
# Load the training dataset containing SMILES strings and their activity labels.

# %%
orig_training_data = pd.read_csv("training_smiles.csv")

# %%
orig_training_data.shape
# Out:
# (202895, 3)

# %% [markdown]
# ## Step 2: Convert SMILES to Molecule Objects
#
# Convert SMILES strings (text representations of molecules) into RDKit molecule objects so we can extract chemical properties.
#
# **Example:** `"CCO"` represents ethanol (ethyl alcohol)

# %%
orig_training_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202895 entries, 0 to 202894
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   INDEX   202895 non-null  int64
#  1   SMILES  202895 non-null  object
#  2   ACTIVE  202895 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.6+ MB

# %% [markdown]
# Create a copy of the data for feature extraction.

# %%
features_df = orig_training_data.copy()

# %%
from rdkit import Chem


features_df["SMILES"] = features_df["SMILES"].astype("string")
features_df["MolFromSmiles"] = features_df["SMILES"].apply(Chem.MolFromSmiles)
# Out:
# [14:10:48] WARNING: not removing hydrogen atom without neighbors

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202895 entries, 0 to 202894
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   INDEX          202895 non-null  int64
#  1   SMILES         202895 non-null  string
#  2   ACTIVE         202895 non-null  float64
#  3   MolFromSmiles  202895 non-null  object
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 6.2+ MB
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
features_df[:5]
# Out:
#    INDEX                                             SMILES  ACTIVE  \
# 0      1           O=C(Nc1ccc2c(c1)OCCO2)C1CCN(c2ncccn2)CC1     0.0
# 1      2  COCCCN1C(=O)C2C(C(=O)Nc3cccc(Cl)c3)C3C=CC2(O3)...     0.0
# 2      3                   CCSc1ncc(Cl)c(C(=O)Nc2ccccc2C)n1     0.0
# 3      4  COc1ccc2cc(/C=N/NC(=O)CN(c3ccccc3C)S(=O)(=O)c3...     0.0
# 4      5  CCCC(=O)Nc1nc2ccc(NC(=O)c3c(F)c(F)c(OC)c(F)c3F...     0.0
#
#                                    MolFromSmiles
# 0  <rdkit.Chem.rdchem.Mol object at 0x167143c30>
# 1  <rdkit.Chem.rdchem.Mol object at 0x1671b65e0>
# 2  <rdkit.Chem.rdchem.Mol object at 0x1671b6490>
# 3  <rdkit.Chem.rdchem.Mol object at 0x1671b6500>
# 4  <rdkit.Chem.rdchem.Mol object at 0x1671b6570>

# %% [markdown]
# ## Step 3: Extract Basic Molecular Features
#
# Extract fundamental properties of each molecule:
# - **NumAtoms**: Total number of atoms in the molecule
# - **NumHeavyAtoms**: Number of heavy (non-hydrogen) atoms
# - **NumBonds**: Total number of chemical bonds

# %%
features_df["NumAtoms"] = features_df["MolFromSmiles"].apply(lambda m: m.GetNumAtoms() if m is not None else None)
# same func found in lipnski
features_df["NumHeavyAtoms"] = features_df["MolFromSmiles"].apply(lambda m: m.GetNumHeavyAtoms() if m is not None else None)
features_df["NumBonds"] = features_df["MolFromSmiles"].apply(lambda m: m.GetNumBonds() if m is not None else None)
features_df.head()
# Out:
#    INDEX                                             SMILES  ACTIVE  \
# 0      1           O=C(Nc1ccc2c(c1)OCCO2)C1CCN(c2ncccn2)CC1     0.0
# 1      2  COCCCN1C(=O)C2C(C(=O)Nc3cccc(Cl)c3)C3C=CC2(O3)...     0.0
# 2      3                   CCSc1ncc(Cl)c(C(=O)Nc2ccccc2C)n1     0.0
# 3      4  COc1ccc2cc(/C=N/NC(=O)CN(c3ccccc3C)S(=O)(=O)c3...     0.0
# 4      5  CCCC(=O)Nc1nc2ccc(NC(=O)c3c(F)c(F)c(OC)c(F)c3F...     0.0
#
#                                    MolFromSmiles  NumAtoms  NumBonds  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x167143c30>        25        28
# 1  <rdkit.Chem.rdchem.Mol object at 0x1671b65e0>        35        39
# 2  <rdkit.Chem.rdchem.Mol object at 0x1671b6490>        20        21
# 3  <rdkit.Chem.rdchem.Mol object at 0x1671b6500>        36        39
# 4  <rdkit.Chem.rdchem.Mol object at 0x1671b6570>        30        32
#
#    NumHeavyAtoms
# 0             25
# 1             35
# 2             20
# 3             36
# 4             30

# %% [markdown]
# Check how many molecules have hydrogen atoms (NumAtoms != NumHeavyAtoms).

# %%
# only 6... not significant?
len(features_df.query('NumAtoms != NumHeavyAtoms'))
# Out:
# 6

# %% [markdown]
# ## Step 4: Extract Fragment Features
#
# Identify specific chemical fragments/substructures in each molecule (e.g., benzene rings, aldehydes, alcohols).
#
# These features help identify common chemical patterns that may be important for biological activity.

# %%
from rdkit.Chem import Fragments as f

frag_methods = [m for m in dir(f) if m.startswith("fr_")]

for frag in frag_methods:
    func = getattr(f, frag)
    features_df[frag] = features_df["MolFromSmiles"].apply(
        lambda m, fn=func: fn(m) if m is not None else None
    )

# %% [markdown]
# ## Step 5: Extract Lipinski Features (Drug-Likeness)
#
# Extract features based on **Lipinski's Rule of Five**, which predicts drug-likeness:
# - **NumHDonors**: Number of hydrogen bond donors
# - **NumHAcceptors**: Number of hydrogen bond acceptors
# - **NumRotatableBonds**: Number of rotatable bonds (flexibility)
# - **FractionCSP3**: Fraction of sp3 hybridized carbons
# - And many more...
#
# These features help predict if a molecule has properties suitable for oral drug administration.

# %%
from rdkit.Chem import Lipinski as l
test_mol = next(m for m in features_df["MolFromSmiles"] if m is not None)

numeric_lipinski = []
for name in dir(l):
    attr = getattr(l, name)
    if callable(attr):
        try:
            result = attr(test_mol)
            if isinstance(result, (int, float)):
                numeric_lipinski.append(name)
        except:
            pass 
                

print("Numeric Lipinski functions:", numeric_lipinski)

for func_name in numeric_lipinski:
    fn = getattr(l, func_name)
    features_df[func_name] = features_df["MolFromSmiles"].apply(
        lambda m, fn=fn: fn(m) if m is not None else None
    )
# Out:
# Numeric Lipinski functions: ['FractionCSP3', 'HeavyAtomCount', 'NHOHCount', 'NOCount', 'NumAliphaticCarbocycles', 'NumAliphaticHeterocycles', 'NumAliphaticRings', 'NumAmideBonds', 'NumAromaticCarbocycles', 'NumAromaticHeterocycles', 'NumAromaticRings', 'NumAtomStereoCenters', 'NumBridgeheadAtoms', 'NumHAcceptors', 'NumHDonors', 'NumHeteroatoms', 'NumHeterocycles', 'NumRotatableBonds', 'NumSaturatedCarbocycles', 'NumSaturatedHeterocycles', 'NumSaturatedRings', 'NumSpiroAtoms', 'NumUnspecifiedAtomStereoCenters', 'Phi', 'RingCount', '_cfn', '_fn']

# %% [markdown]
# ## Step 6: Extract Advanced Molecular Descriptors
#
# Extract ~40+ advanced molecular descriptors including:
# - **Molecular weight** and **exact mass**
# - **Polar surface area (TPSA)**: Important for membrane permeability
# - **Chirality** and **stereochemistry** information
# - **Ring counts** and **cycle types**
# - **Topological indices** (connectivity, shape descriptors)
# - And many more...
#
# *Note: Some warnings about "no conformers" are expected - these descriptors require 3D structures, but we're using 2D information.*

# %%
import rdkit.Chem.rdMolDescriptors as d

test_mol = next(m for m in features_df["MolFromSmiles"] if m is not None)

numeric_rdmol= []
for name in dir(d):
    attr = getattr(d, name)
    if callable(attr):
        try:
            result = attr(test_mol)
            if isinstance(result, (int, float)):
                numeric_rdmol.append(name)
        except:
            pass 
                

print("Numeric RDMolDesc functions:", numeric_rdmol)

for func_name in numeric_rdmol:
    fn = getattr(d, func_name)
    features_df[func_name] = features_df["MolFromSmiles"].apply(
        lambda m, fn=fn: fn(m) if m is not None else None
    )
# Out:
# [14:29:59]
#
# ****
# Pre-condition Violation
# molecule has no conformers
# Violation occurred on line 233 in file /Users/runner/miniforge3/conda-bld/rdkit-meta_1764390867374/work/Code/GraphMol/Descriptors/AUTOCORR3D.cpp
# Failed Expression: mol.getNumConformers() >= 1
# ****
#
# [14:29:59]
#
# ****
# Pre-condition Violation
# molecule has no conformers
# Violation occurred on line 208 in file /Users/runner/miniforge3/conda-bld/rdkit-meta_1764390867374/work/Code/GraphMol/Descriptors/PMI.cpp
# Failed Expression: mol.getNumConformers() >= 1
# ****
#
# [14:29:59]
#
# ****
# Pre-condition Violation
# molecule has no conformers
# Violation occurred on line 40 in file /Users/runner/miniforge3/conda-bld/rdkit-meta_1764390867374/work/Code/GraphMol/Descriptors/CoulombMat.cpp
# Failed Expression: mol.getNumConformers() >= 1
# ****
#
# [14:29:59]
#
# ****
# Pre-condition Violation
# molecule has no conformers
# ...

# %% [markdown]
# View summary of all extracted features. The dataset now contains ~163 columns with various molecular properties.
#
# ## Step 7: Save Features to CSV
#
# Save all extracted features (~163 columns) to `training_features.csv` for use in machine learning models.
#
# **Final dataset contains:**
# - Original columns: INDEX, SMILES, ACTIVE
# - ~160 new feature columns extracted from molecular structures

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202895 entries, 0 to 202894
# Columns: 163 entries, INDEX to _CalcMolWt
# dtypes: float64(25), int64(136), object(1), string(1)
# memory usage: 252.3+ MB

# %%
features_df.to_csv("training_features.csv")

# %%
features_df.head()
# Out:
#    INDEX                                             SMILES  ACTIVE  \
# 0      1           O=C(Nc1ccc2c(c1)OCCO2)C1CCN(c2ncccn2)CC1     0.0
# 1      2  COCCCN1C(=O)C2C(C(=O)Nc3cccc(Cl)c3)C3C=CC2(O3)...     0.0
# 2      3                   CCSc1ncc(Cl)c(C(=O)Nc2ccccc2C)n1     0.0
# 3      4  COc1ccc2cc(/C=N/NC(=O)CN(c3ccccc3C)S(=O)(=O)c3...     0.0
# 4      5  CCCC(=O)Nc1nc2ccc(NC(=O)c3c(F)c(F)c(OC)c(F)c3F...     0.0
#
#                                    MolFromSmiles  NumAtoms  NumBonds  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x167143c30>        25        28
# 1  <rdkit.Chem.rdchem.Mol object at 0x1671b65e0>        35        39
# 2  <rdkit.Chem.rdchem.Mol object at 0x1671b6490>        20        21
# 3  <rdkit.Chem.rdchem.Mol object at 0x1671b6500>        36        39
# 4  <rdkit.Chem.rdchem.Mol object at 0x1671b6570>        30        32
#
#    NumHeavyAtoms  fr_Al_COO  fr_Al_OH  fr_Al_OH_noTert  ...  CalcNumRings  \
# ...
